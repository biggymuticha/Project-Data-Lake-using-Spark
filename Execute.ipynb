# %%
## Execute ETL script

# %%
# %run -i etl.py
# Out:
# Processing song data in s3a://udacity-dend/ ...
# Scanning folders with json files.....
# s3a://udacity-dend/song_data/A/A/A/
# s3a://udacity-dend/song_data/A/A/B/
# s3a://udacity-dend/song_data/A/A/C/
# s3a://udacity-dend/song_data/A/A/D/
# s3a://udacity-dend/song_data/A/A/E/
# s3a://udacity-dend/song_data/A/A/F/
# s3a://udacity-dend/song_data/A/A/G/
# s3a://udacity-dend/song_data/A/A/H/
# s3a://udacity-dend/song_data/A/A/I/
# s3a://udacity-dend/song_data/A/A/J/
# s3a://udacity-dend/song_data/A/A/K/
# s3a://udacity-dend/song_data/A/A/L/
# s3a://udacity-dend/song_data/A/A/M/
# s3a://udacity-dend/song_data/A/A/N/
# s3a://udacity-dend/song_data/A/A/O/
# s3a://udacity-dend/song_data/A/A/P/
# s3a://udacity-dend/song_data/A/A/Q/
# s3a://udacity-dend/song_data/A/A/R/
# s3a://udacity-dend/song_data/A/A/S/
# s3a://udacity-dend/song_data/A/A/T/
# s3a://udacity-dend/song_data/A/A/U/
# s3a://udacity-dend/song_data/A/A/V/
# s3a://udacity-dend/song_data/A/A/W/
# ...
